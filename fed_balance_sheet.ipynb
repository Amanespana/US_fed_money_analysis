# %%
import pandas as pd

# %%
df = pd.read_excel("FRB_H41.xlsx")
df.head()
# Out:
#   Time Period  \
# 0  2002-12-18
# 1  2002-12-25
# 2  2003-01-01
# 3  2003-01-08
# 4  2003-01-15
#
#    Liabilities and Capital: Other Factors Draining Reserve Balances: Treasury Contribution to Credit Facilities (Effective 2020-05-07): Wednesday level  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Liabilities and Capital: Other Factors Draining Reserve Balances: Treasury Contribution to Credit Facilities (Effective 2020-05-07): change in Wednesday level from previous Wednesday level  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
cols = df.columns.to_list()

# %%
#cols

# %%
my_series=df.isin([8342231]).any()

# %%
my_series[my_series==True].index[0]
# Out:
# 'Liabilities and Capital: Liabilities: Total liabilities (Less eliminations from consolidation): Wednesday level'

# %%
assets = df.isin([8384767]).any()[df.isin([8384767]).any()==True].index[0]
liabilities = my_series[my_series==True].index[0]

# %%
df.head()
# Out:
#   Time Period  \
# 0  2002-12-18
# 1  2002-12-25
# 2  2003-01-01
# 3  2003-01-08
# 4  2003-01-15
#
#    Liabilities and Capital: Other Factors Draining Reserve Balances: Treasury Contribution to Credit Facilities (Effective 2020-05-07): Wednesday level  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Liabilities and Capital: Other Factors Draining Reserve Balances: Treasury Contribution to Credit Facilities (Effective 2020-05-07): change in Wednesday level from previous Wednesday level  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
df.get(['Time Period', assets, liabilities])

# %%
df1= df[['Time Period', assets, liabilities]].rename(columns = {assets: 'Total Assets', liabilities: 'Total Liabilities'})

# %%
df1
# Out:
#      Time Period  Total Assets  Total Liabilities
# 0     2002-12-18        719542             702053
# 1     2002-12-25        732059             713850
# 2     2003-01-01        730994             714234
# 3     2003-01-08        723762             706601
# 4     2003-01-15        720074             702678
# ...          ...           ...                ...
# 1048  2023-01-18       8489039            8447213
# 1049  2023-01-25       8470557            8428731
# 1050  2023-02-01       8433610            8391769
# 1051  2023-02-08       8435369            8392837
# 1052  2023-02-15       8384767            8342231
#
# [1053 rows x 3 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1053 entries, 0 to 1052
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time Period        1053 non-null   datetime64[ns]
#  1   Total Assets       1053 non-null   int64
#  2   Total Liabilities  1053 non-null   int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 24.8 KB
