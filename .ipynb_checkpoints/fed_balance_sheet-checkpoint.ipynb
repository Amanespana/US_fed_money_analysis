# %%
import pandas as pd

# %%
df = pd.read_excel("FRB_H41.xlsx")
df.head()
# Out:
#   Time Period  \
# 0  2002-12-18
# 1  2002-12-25
# 2  2003-01-01
# 3  2003-01-08
# 4  2003-01-15
#
#    Liabilities and Capital: Other Factors Draining Reserve Balances: Treasury Contribution to Credit Facilities (Effective 2020-05-07): Wednesday level  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Liabilities and Capital: Other Factors Draining Reserve Balances: Treasury Contribution to Credit Facilities (Effective 2020-05-07): change in Wednesday level from previous Wednesday level  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
#Get Total Assets and Liabilities columns from 135 columns
assets_mask=df.isin([8384767]).any()
total_assets = assets_mask[assets_mask==True].index[0]
print(total_assets)


liab_mask  = df.isin([8342231]).any()
total_liab = liab_mask[liab_mask==True].index[0]
print(total_liab)
# Out:
# Assets: Total Assets: Total assets (Less eliminations from consolidation): Wednesday level
# Liabilities and Capital: Liabilities: Total liabilities (Less eliminations from consolidation): Wednesday level

# %%
df1 = df.get(['Time Period', total_assets, total_liab]).rename(columns = {total_assets: 'Total Assets', total_liab: 'Total Liabilities'}).copy()

# %%
df1
# Out:
#      Time Period  Total Assets  Total Liabilities
# 0     2002-12-18        719542             702053
# 1     2002-12-25        732059             713850
# 2     2003-01-01        730994             714234
# 3     2003-01-08        723762             706601
# 4     2003-01-15        720074             702678
# ...          ...           ...                ...
# 1048  2023-01-18       8489039            8447213
# 1049  2023-01-25       8470557            8428731
# 1050  2023-02-01       8433610            8391769
# 1051  2023-02-08       8435369            8392837
# 1052  2023-02-15       8384767            8342231
#
# [1053 rows x 3 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1053 entries, 0 to 1052
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time Period        1053 non-null   datetime64[ns]
#  1   Total Assets       1053 non-null   int64
#  2   Total Liabilities  1053 non-null   int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 24.8 KB

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# Discontinued: Assets: Net Portfolio Holdings of Maiden Lane LLCs: Net portfolio holdings of Maiden Lane LLC: change in Wednesday level from previous Wednesday level    153
# Discontinued: Assets: Net Portfolio Holdings of Maiden Lane LLCs: Net portfolio holdings of Maiden Lane LLC: change in Wednesday level from year ago level              153
# dtype: int64

# %%
zero_values = df==0

# %%
rcol = 'Liabilities and Capital: Other Factors Draining Reserve Balances: Treasury Contribution to Credit Facilities (Effective 2020-05-07): Wednesday level'

# %%
zerp_values[rcol]==True
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1048    False
# 1049    False
# 1050    False
# 1051    False
# 1052    False
# Name: Liabilities and Capital: Other Factors Draining Reserve Balances: Treasury Contribution to Credit Facilities (Effective 2020-05-07): Wednesday level, Length: 1053, dtype: bool

# %%
for col in zero_values.columns.to_list():
    print(zero_values[col].value_counts()[0])
# Out:
# 1053
# 908
# 1040
# 908
# 725
# 612
# 773
# 911
# 911
# 911
# 912
# 913
# 912
# 551
# 750
# 914
# 952
# 914
# 1053
# 1026
# 1050
# 1053
# 1036
# 889
# 1053
# 1053
# 1053
# 1051
